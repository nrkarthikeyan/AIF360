# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dennislwei/icx/blob/master/examples/mexgen/quick_start.ipynb)

# %% [markdown]
# General tip for colab - change the runtime type to GPU for faster run
#
# **RUNNING COLAB NOTEBOOK FROM A PRIVATE REPO**
#
# - Make sure you are a member of the repo.
# - Go to https://colab.research.google.com/, open "Settings", and in "Github" click "Authorize with Github" and follow the steps. Make sure to enable "Access private repositories and organizations".
# - Generate an access token from github:
#     - Goto https://github.com/settings/tokens/new -> in the scopes select "repo" and "read:org". Generate the token and save a copy - you won't see it again after you navigate away from the page.
# - Run commands in the "Install ICX360 for Colab" section

# %% [markdown]
# **TODO BEFORE OSS RELEASE:**
# - change google colab url, change any RITS references

# %% [markdown]
# # MExGen Quick Start

# %% [markdown]
# This notebook shows a simple example of using MExGen (Multi-Level Explanations for Generative Language Models) to get users started. For more complete examples, please see the notebooks on [question answering](https://github.com/dennislwei/icx/blob/master/examples/mexgen/question_answering.ipynb), [summarization](https://github.com/dennislwei/icx/blob/master/examples/mexgen/summarization.ipynb), and [RAG](https://github.com/dennislwei/icx/blob/master/examples/mexgen/RAG.ipynb).

# %% [markdown]
# ### Install ICX360 for Colab (for private repo) - skip if you have icx360 installed:

# %%
# Get the github token securely
from getpass import getpass
token = getpass("Enter your GitHub Personal Access Token: ")

# Clone the private
# !sudo apt install gh
# !echo "$token" | gh auth login --hostname github.com --with-token
# !gh auth status | echo
# !rm -rf icx
# !git clone https://$token@github.com/dennislwei/icx.git

# This installs the package anyway. Need to fix this issue.
# %cd "icx"
# !pip install uv
# !uv pip install .
# %cd ..
# Out:
# Streaming output truncated to the last 5000 lines.
# nvidia-curand-cu12         ------------------------------ 1.12 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.21 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.11 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.41 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.14 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 9.47 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠴ Preparing packages... (26/48)
# bert-score                 ------------------------------ 48.00 KiB/59.70 KiB
# jupyter-client             ------------------------------ 123.50 KiB/130.36 KiB
# jupyter-server             ------------------------------ 155.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 489.50 KiB/863.02 KiB
# jedi                       ------------------------------ 173.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 48.00 KiB/5.78 MiB
# jupyterlab                 ------------------------------ 108.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 1.42 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.11 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.22 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.12 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.21 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.11 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.41 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.14 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 9.74 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠴ Preparing packages... (26/48)
# jupyter-client             ------------------------------ 123.50 KiB/130.36 KiB
# jupyter-server             ------------------------------ 155.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 489.50 KiB/863.02 KiB
# jedi                       ------------------------------ 189.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 77.98 KiB/5.78 MiB
# jupyterlab                 ------------------------------ 108.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 1.49 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.19 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.31 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.22 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.28 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.20 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.47 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.20 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 9.74 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠴ Preparing packages... (26/48)
# jupyter-server             ------------------------------ 155.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 489.50 KiB/863.02 KiB
# jedi                       ------------------------------ 189.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 77.98 KiB/5.78 MiB
# jupyterlab                 ------------------------------ 108.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 1.49 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.19 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.31 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.22 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.28 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.20 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.47 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.20 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 9.74 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠴ Preparing packages... (26/48)
# jupyter-server             ------------------------------ 155.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 489.50 KiB/863.02 KiB
# jedi                       ------------------------------ 221.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 77.98 KiB/5.78 MiB
# jupyterlab                 ------------------------------ 108.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 1.57 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.27 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.32 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.28 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.35 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.28 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.55 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.28 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 10.42 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠴ Preparing packages... (26/48)
# jupyter-server             ------------------------------ 155.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 489.50 KiB/863.02 KiB
# jedi                       ------------------------------ 221.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 77.98 KiB/5.78 MiB
# jupyterlab                 ------------------------------ 108.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 1.62 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.33 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.39 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.36 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.39 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.28 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.60 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.34 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 10.61 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠴ Preparing packages... (26/48)
# jupyter-server             ------------------------------ 203.87 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 541.51 KiB/863.02 KiB
# jedi                       ------------------------------ 237.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 93.98 KiB/5.78 MiB
# jupyterlab                 ------------------------------ 108.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 1.76 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.50 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.56 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.50 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.56 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.51 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.75 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.48 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 12.74 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠦ Preparing packages... (32/48)
# jupyter-server             ------------------------------ 219.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 621.51 KiB/863.02 KiB
# jedi                       ------------------------------ 237.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 1.57 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 124.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 1.91 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.64 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.59 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.55 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.72 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.68 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 1.93 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.66 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 13.39 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠦ Preparing packages... (32/48)
# jupyter-server             ------------------------------ 219.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 829.51 KiB/863.02 KiB
# jedi                       ------------------------------ 253.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 1.87 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 140.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 2.13 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.87 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 1.90 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.88 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 1.93 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.87 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 2.12 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.81 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 14.59 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠦ Preparing packages... (32/48)
# jupyter-server             ------------------------------ 235.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 861.51 KiB/863.02 KiB
# jedi                       ------------------------------ 253.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 1.97 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 140.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 2.41 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 1.95 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 2.18 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 1.99 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 2.18 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 1.96 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 2.39 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 1.91 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 14.85 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠦ Preparing packages... (32/48)
# jupyter-server             ------------------------------ 235.98 KiB/377.84 KiB
# nvidia-cuda-runtime-cu12   ------------------------------ 861.51 KiB/863.02 KiB
# jedi                       ------------------------------ 253.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 2.27 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 140.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 2.55 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 2.28 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 2.36 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 2.31 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 2.32 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 2.28 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 2.56 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 2.23 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 16.01 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠧ Preparing packages... (32/48)
# jupyter-server             ------------------------------ 351.98 KiB/377.84 KiB
# jedi                       ------------------------------ 253.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 2.38 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 140.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 2.69 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 2.41 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 2.50 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 2.45 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 2.46 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 2.39 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 2.71 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 2.37 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 16.43 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠧ Preparing packages... (32/48)
# jupyter-server             ------------------------------ 367.98 KiB/377.84 KiB
# jedi                       ------------------------------ 269.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 2.55 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 140.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 2.86 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 2.59 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 2.62 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 2.60 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 2.61 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 2.56 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 2.86 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 2.56 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 16.76 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠧ Preparing packages... (32/48)
# jedi                       ------------------------------ 269.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 2.73 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 156.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 3.01 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 2.75 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 2.81 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 2.75 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 2.75 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 2.73 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 3.01 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 2.70 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 17.05 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠧ Preparing packages... (32/48)
# jedi                       ------------------------------ 269.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 2.93 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 156.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 3.19 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 2.76 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 2.97 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 2.89 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 2.92 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 2.90 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 3.15 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 2.87 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 17.05 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠧ Preparing packages... (32/48)
# jedi                       ------------------------------ 269.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 3.11 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 172.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 3.37 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 3.12 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 3.14 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 3.06 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 3.09 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 3.05 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 3.36 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 3.06 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 17.65 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠧ Preparing packages... (32/48)
# jedi                       ------------------------------ 285.32 KiB/1.50 MiB
# virtualenv                 ------------------------------ 3.28 MiB/5.78 MiB
# jupyterlab                 ------------------------------ 412.43 KiB/11.73 MiB
# nvidia-cuda-cupti-cu12     ------------------------------ 3.56 MiB/13.17 MiB
# nvidia-nvjitlink-cu12      ------------------------------ 3.28 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12     ------------------------------ 3.31 MiB/23.50 MiB
# nvidia-curand-cu12         ------------------------------ 3.25 MiB/53.70 MiB
# nvidia-cusolver-cu12       ------------------------------ 3.26 MiB/122.01 MiB
# nvidia-cusparse-cu12       ------------------------------ 3.25 MiB/197.84 MiB
# nvidia-cufft-cu12          ------------------------------ 3.54 MiB/201.66 MiB
# nvidia-cublas-cu12         ------------------------------ 3.25 MiB/346.60 MiB
# en-core-web-trf            ------------------------------ 18.63 MiB/436.23 MiB
#    Building icx360 @ file:///content/icx
#       Built detect-secrets @ git+https://github.com/ibm/detect-secrets.git@cb803c6f7
# ⠇ Preparing packages... (34/48)
# jedi                       ------------------------------ 285.32 KiB/1.50 MiB
# virtualenv                 ------------------------------
Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 396.74 MiB/436.23 MiB
# ⠇ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 398.32 MiB/436.23 MiB
# ⠇ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 399.87 MiB/436.23 MiB
# ⠇ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 401.57 MiB/436.23 MiB
# ⠋ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 402.74 MiB/436.23 MiB
# ⠋ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 404.30 MiB/436.23 MiB
# ⠋ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 405.87 MiB/436.23 MiB
# ⠋ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 406.54 MiB/436.23 MiB
# ⠙ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 407.50 MiB/436.23 MiB
# ⠙ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 409.13 MiB/436.23 MiB
# ⠙ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 410.35 MiB/436.23 MiB
# ⠙ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 411.43 MiB/436.23 MiB
# ⠹ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 412.87 MiB/436.23 MiB
# ⠹ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 414.55 MiB/436.23 MiB
# ⠹ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 415.68 MiB/436.23 MiB
# ⠹ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 416.46 MiB/436.23 MiB
# ⠸ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 418.50 MiB/436.23 MiB
# ⠸ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 419.86 MiB/436.23 MiB
# ⠸ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 421.60 MiB/436.23 MiB
# ⠸ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 423.23 MiB/436.23 MiB
# ⠼ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 424.72 MiB/436.23 MiB
# ⠼ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 426.54 MiB/436.23 MiB
# ⠼ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 428.24 MiB/436.23 MiB
# ⠼ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 429.58 MiB/436.23 MiB
# ⠴ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 431.20 MiB/436.23 MiB
# ⠴ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 432.87 MiB/436.23 MiB
# ⠴ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 433.63 MiB/436.23 MiB
# ⠴ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 434.67 MiB/436.23 MiB
# ⠦ Preparing packages... (46/48)
# en-core-web-trf            ------------------------------ 435.93 MiB/436.23 MiB
# ⠦ Preparing packages... (46/48)
# ⠦ Preparing packages... (46/48)
# ⠦ Preparing packages... (46/48)
# ⠦ Preparing packages... (46/48)
# ⠧ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠹ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠴ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠹ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠴ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠹ Preparing packages... (47/48)
# ⠹ Preparing packages... (47/48)
# ⠹ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠸ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠼ Preparing packages... (47/48)
# ⠴ Preparing packages... (47/48)
# ⠴ Preparing packages... (47/48)
# ⠴ Preparing packages... (47/48)
# ⠴ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠦ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠧ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠇ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠋ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# ⠙ Preparing packages... (47/48)
# Prepared 48 packages in 48.90s
# Uninstalled 13 packages in 49ms
# Installed 48 packages in 151ms
#  + arrow==1.3.0
#  + async-lru==2.0.5
#  + bert-score==0.3.13
#  + binaryornot==0.4.4
#  + boxsdk==3.14.0
#  + cfgv==3.4.0
#  + curated-tokenizers==0.0.9
#  + curated-transformers==0.1.1
#  + detect-secrets==0.13.1+ibm.62.dss (from git+https://github.com/ibm/detect-secrets.git@cb803c6f7883b631b9aa9c8664b0937a9d358609)
#  + distlib==0.3.9
#  + en-core-web-trf==3.8.0 (from https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.8.0/en_core_web_trf-3.8.0-py3-none-any.whl)
#  + evaluate==0.4.5
#  + fqdn==1.5.1
#  + icx360==0.1.0 (from file:///content/icx)
#  + identify==2.6.12
#  + isoduration==20.11.0
#  + jedi==0.19.2
#  + json5==0.12.0
#  - jupyter-client==6.1.12
#  + jupyter-client==7.4.9
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.2.5
#  - jupyter-server==1.16.0
#  + jupyter-server==2.16.0
#  + jupyter-server-terminals==0.5.3
#  + jupyterlab==4.4.4
#  + jupyterlab-server==2.27.3
#  + nodeenv==1.9.1
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + overrides==7.7.0
#  + pre-commit==4.2.0
#  + python-dotenv==1.1.1
#  + python-json-logger==3.3.0
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + spacy-curated-transformers==0.3.1
#  + toma==1.1.0
#  + types-python-dateutil==2.9.0.20250708
#  + uri-template==1.3.0
#  - urllib3==2.4.0
#  + urllib3==1.26.20
#  + virtualenv==20.31.2
# /content

# %%
# %%bash

# UNAME="dennislwei"
# FOLDER="icx"
# REPO="github.com/${UNAME}/${FOLDER}"
# PACKAGE="icx360"
# echo $REPO

# sudo apt install gh
# echo "$token" | gh auth login --hostname github.com --with-token
# rm -rf $FOLDER
# git clone https://$token@github.com/$UNAME/${FOLDER}.git

# %%
# !https://$token@github.com/$UNAME/${FOLDER}.git

# %%
# %%bash
# UNAME="dennislwei"
# FOLDER="icx"
# REPO="github.com/${UNAME}/${FOLDER}"
# PACKAGE="icx360"
# echo $REPO

# if python -c "import $PACKAGE" &> /dev/null; then
#     echo "Package '$PACKAGE' is already installed."
# else
#     echo "Package '$PACKAGE' is not installed. Cleaning existing folder and downloading ..."
#     sudo apt install gh
#     rm -rf $FOLDER

#     # Clone the repo with error handling
#     if gh repo clone $REPO; then
#         echo "Repository cloned successfully."
#     else
#         echo "Error: Failed to clone the repository, reauthenticating and trying again ..."
#         echo "$token" | gh auth login --hostname github.com --with-token
#         if gh repo clone $REPO; then
#             echo "Repository cloned successfully."
#         else
#             echo "Error: Failed again, quitting ..."
#         fi
#     fi
# fi

# %%
# !cd icx; ls

# %% [markdown]
# ### Import packages

# %% [markdown]
# Standard packages

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import torch
from transformers import BartForConditionalGeneration, BartTokenizerFast
from IPython.display import display

# %% [markdown]
# ICX360 classes

# %%
from icx360.algorithms.mexgen import CLIME    # explainer
from icx360.utils.general_utils import select_device    # set device automatically
from icx360.utils.model_wrappers import HFModel    # model wrapper

# %%
device = select_device()
display(device)
# Out:
# device(type='cuda')

# %% [markdown]
# ### Load input

# %% [markdown]
# The task for this example is summarization, using a document from the Extreme Summarization (XSum) dataset. For convenience, the document has been saved to a file that we will load.

# %%
# with open("quick_start_doc.txt", "r") as f:
#     document = f.read()
# print(document)

document = """On Thursday, a human skull was found alongside the M54 slip road by workers doing a survey of the junction four roundabout, near Telford.
Police confirmed the skull was that of an adult male and had been there for at least two years.
West Mercia Police said "further skeletal remains" were found close to the skull.
The eastbound entry slip road remains partially closed.
Det Chief Insp Neil Jamieson said: "We are in the very early stages of this investigation and inquiries are ongoing."
He said further forensic examinations and excavations were being carried out and police had been in contact with neighbouring forces asking for information about people who had been reported missing.
Archaeological experts may be called in to help with the investigation.
"This will be a lengthy process but we will continue to update the public in due course," he added."""
print(document)
# Out:
# On Thursday, a human skull was found alongside the M54 slip road by workers doing a survey of the junction four roundabout, near Telford.
# Police confirmed the skull was that of an adult male and had been there for at least two years.
# West Mercia Police said "further skeletal remains" were found close to the skull.
# The eastbound entry slip road remains partially closed.
# Det Chief Insp Neil Jamieson said: "We are in the very early stages of this investigation and inquiries are ongoing."
# He said further forensic examinations and excavations were being carried out and police had been in contact with neighbouring forces asking for information about people who had been reported missing.
# Archaeological experts may be called in to help with the investigation.
# "This will be a lengthy process but we will continue to update the public in due course," he added.

# %% [markdown]
# The document can also be retrieved from the dataset (and other examples can be loaded) by uncommenting the following cell:

# %%
# from datasets import load_dataset
# dataset = load_dataset('xsum', split='test', trust_remote_code=True)
# document = dataset["document"][88]
# print(document)

# %% [markdown]
# ### Load model to explain

# %% [markdown]
# We will use a small summarization model from HuggingFace that can be run on a CPU only (although a GPU would be significantly faster).

# %%
model_name = "sshleifer/distilbart-xsum-12-6"
model = BartForConditionalGeneration.from_pretrained(model_name).to(device)
tokenizer = BartTokenizerFast.from_pretrained(model_name, add_prefix_space=True)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/611M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/611M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]

# %% [markdown]
# We wrap the model with a common API (`HFModel`) that the explainer will use.

# %%
wrapped_model = HFModel(model, tokenizer)

# %% [markdown]
# ### Instantiate explainer

# %% [markdown]
# Below we instantiate a MExGen C-LIME explainer. This explainer attributes an importance score to each part of the input document by calling the summarization model on perturbed versions of the input. Parameters for the explainer:
# - `scalarizer`: The explainer requires a "scalarizer" to quantify how different are the output summaries for perturbed inputs from the output summary for the original input. For this we use the `"prob"` scalarizer, which computes the probability of generating the original output conditioned on perturbed inputs.
# - `segmenter`: The explainer will use the spaCy model `"en_core_web_sm"` to segment the document into sentences.

# %%
explainer = CLIME(wrapped_model, scalarizer="prob", segmenter="en_core_web_sm")

# %% [markdown]
# ### Call explainer

# %% [markdown]
# We call the explainer's `explain_instance` method on the input document with default parameters. This will attribute an importance score to each sentence in the document. (This may take a minute if running on a CPU.)

# %%
output_dict = explainer.explain_instance(document)
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.58.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# toma_get_probs batch size = 37

# %% [markdown]
# ### Look at output

# %% [markdown]
# The explainer returns a dictionary. The `"output_orig"` item shows the output summary for the original document.

# %%
display(output_dict["output_orig"].output_text)
# Out:
# ['Police investigating the discovery of a human skull on a motorway in Shropshire have said further skeletal remains have been found.']

# %% [markdown]
# The `"attributions"` item contains the sentences (`"units"`) that the document has been split into along with their importance scores (`"prob"`). These are displayed below as a pandas DataFrame.

# %%
df1 = pd.DataFrame(output_dict["attributions"])[["units", "prob", "unit_types"]].sort_values(
                                by='prob', ascending=False, inplace=False)
styles = [
    {'selector': '.col0', 'props': [('width', '450px'), ('font-weight', 'bold')]}, # units
    {'selector': '.col1', 'props': [('width', '50px')]}, # prob
    {'selector': '.col2', 'props': [('width', '50px')]}, # unit_types
    ]
styled = df1.style.set_table_styles(styles)

display(styled)
# Out:
# <style type="text/css">
# #T_b1e0f .col0 {
#   width: 450px;
#   font-weight: bold;
# }
# #T_b1e0f .col1 {
#   width: 50px;
# }
# #T_b1e0f .col2 {
#   width: 50px;
# }
# </style>
# <table id="T_b1e0f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1e0f_level0_col0" class="col_heading level0 col0" >units</th>
#       <th id="T_b1e0f_level0_col1" class="col_heading level0 col1" >prob</th>
#       <th id="T_b1e0f_level0_col2" class="col_heading level0 col2" >unit_types</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1e0f_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_b1e0f_row0_col0" class="data row0 col0" >West Mercia Police said "further skeletal remains" were found close to the skull.
# </td>
#       <td id="T_b1e0f_row0_col1" class="data row0 col1" >0.629328</td>
#       <td id="T_b1e0f_row0_col2" class="data row0 col2" >s</td>
#     </tr>
#     <tr>
#       <th id="T_b1e0f_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_b1e0f_row1_col0" class="data row1 col0" >On Thursday, a human skull was found alongside the M54 slip road by workers doing a survey of the junction four roundabout, near Telford.
# </td>
#       <td id="T_b1e0f_row1_col1" class="data row1 col1" >0.514589</td>
#       <td id="T_b1e0f_row1_col2" class="data row1 col2" >s</td>
#     </tr>
#     <tr>
#       <th id="T_b1e0f_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_b1e0f_row2_col0" class="data row2 col0" >Det Chief Insp Neil Jamieson said: "We are in the very early stages of this investigation and inquiries are ongoing.</td>
#       <td id="T_b1e0f_row2_col1" class="data row2 col1" >0.030449</td>
#       <td id="T_b1e0f_row2_col2" class="data row2 col2" >s</td>
#     </tr>
#     <tr>
#       <th id="T_b1e0f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1e0f_row3_col0" class="data row3 col0" >The eastbound entry slip road remains partially closed.
# </td>
#       <td id="T_b1e0f_row3_col1" class="data row3 col1" >0.022306</td>
#       <td id="T_b1e0f_row3_col2" class="data row3 col2" >s</td>
#     </tr>
#     <tr>
#       <th id="T_b1e0f_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_b1e0f_row4_col0" class="data row4 col0" >"This will be a lengthy process but we will continue to update the public in due course," he added.</td>
#       <td id="T_b1e0f_row4_col1" class="data row4 col1" >0.009262</td>
#       <td id="T_b1e0f_row4_col2" class="data row4 col2" >s</td>
#     </tr>
#     <tr>
#       <th id="T_b1e0f_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_b1e0f_row5_col0" class="data row5 col0" >Police confirmed the skull was that of an adult male and had been there for at least two years.
# </td>
#       <td id="T_b1e0f_row5_col1" class="data row5 col1" >0.008356</td>
#       <td id="T_b1e0f_row5_col2" class="data row5 col2" >s</td>
#     </tr>
#     <tr>
#       <th id="T_b1e0f_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_b1e0f_row6_col0" class="data row6 col0" >"
# He said further forensic examinations and excavations were being carried out and police had been in contact with neighbouring forces asking for information about people who had been reported missing.
# </td>
#       <td id="T_b1e0f_row6_col1" class="data row6 col1" >0.008152</td>
#       <td id="T_b1e0f_row6_col2" class="data row6 col2" >s</td>
#     </tr>
#     <tr>
#       <th id="T_b1e0f_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_b1e0f_row7_col0" class="data row7 col0" >Archaeological experts may be called in to help with the investigation.
# </td>
#       <td id="T_b1e0f_row7_col1" class="data row7 col1" >-0.004774</td>
#       <td id="T_b1e0f_row7_col2" class="data row7 col2" >s</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The most important sentence suggests that the model has closely paraphased text ("further skeletal remains have been found"), while the second most important sentence suggests that it also abstracts concepts ("M54 slip road" --> "motorway").
